# %%
import pandas as pd
import folium
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)
seoul_map2 = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', zoom_start=12)
seoul_map3 = folium.Map(location=[37.55,126.98], tiles='Stamen Toner', zoom_start=15)
# 지도를 HTML 파일로 저장하기 
#seoul_map.save('./seoul.html') 
#seoul_map2.save('./seoul2.html') 
#seoul_map2.save('./seoul2.html')

# %%
m = folium.Map( location=[35.1804486,128.5523014], zoom_start=15
)
folium.Marker( location=[35.1804486,128.5523014], popup='University of kyungnam', icon=folium.Icon(color='red',icon='star')
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8effeff8f3938fac19e5ac54103a065 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8effeff8f3938fac19e5ac54103a065&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8effeff8f3938fac19e5ac54103a065 = L.map(
#                 &quot;map_b8effeff8f3938fac19e5ac54103a065&quot;,
#                 {
#                     center: [35.1804486, 128.5523014],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d203090e34a16e1b286ca337a383e6b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8effeff8f3938fac19e5ac54103a065);
#
#
#             var marker_7ba7b5bca1d5c7d5e75225a69ff0f872 = L.marker(
#                 [35.1804486, 128.5523014],
#                 {}
#             ).addTo(map_b8effeff8f3938fac19e5ac54103a065);
#
#
#             var icon_1ab2763c6144ad5056dd30bd726e4754 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ba7b5bca1d5c7d5e75225a69ff0f872.setIcon(icon_1ab2763c6144ad5056dd30bd726e4754);
#
#
#         var popup_f7f5ec8e38cec076a4805247c8865f0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a321fdfbb3fe9d20f34d99bac20bc19a = $(`&lt;div id=&quot;html_a321fdfbb3fe9d20f34d99bac20bc19a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of kyungnam&lt;/div&gt;`)[0];
#                 popup_f7f5ec8e38cec076a4805247c8865f0d.setContent(html_a321fdfbb3fe9d20f34d99bac20bc19a);
#
#
#
#         marker_7ba7b5bca1d5c7d5e75225a69ff0f872.bindPopup(popup_f7f5ec8e38cec076a4805247c8865f0d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.read_excel('data/서울지역 대학교 위치.xlsx') 
df.set_index('학교명', inplace=True)

# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98],tiles='Stamen Terrain', zoom_start=12)

# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

# 지도보기 
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3029d8061b25872a88aff819413b513 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3029d8061b25872a88aff819413b513&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3029d8061b25872a88aff819413b513 = L.map(
#                 &quot;map_e3029d8061b25872a88aff819413b513&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bdf4a7aa984df5f4f4c569ff2886ba9 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3029d8061b25872a88aff819413b513);
#
#
#             var marker_6f7d94b7fde5732f35275d715d2cfd62 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_e3029d8061b25872a88aff819413b513);
#
#
#         var popup_15592e92b0556e12a644add3291357d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b16d0ef6736c032948ff81a41e866c51 = $(`&lt;div id=&quot;html_b16d0ef6736c032948ff81a41e866c51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_15592e92b0556e12a644add3291357d3.setContent(html_b16d0ef6736c032948ff81a41e866c51);
#
#
#
#         marker_6f7d94b7fde5732f35275d715d2cfd62.bindPopup(popup_15592e92b0556e12a644add3291357d3)
#         ;
#
#
#
#
#             var marker_97c38ad812624abb174591f2d9b26fe7 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_e3029d8061b25872a88aff819413b513);
#
#
#         var popup_118a48da1344b36f4a90f1c632da8a51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_627070e8416fc7adf878ca5950a44559 = $(`&lt;div id=&quot;html_627070e8416fc7adf878ca5950a44559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_118a48da1344b36f4a90f1c632da8a51.setContent(html_627070e8416fc7adf878ca5950a44559);
#
#
#
#         marker_97c38ad812624abb174591f2d9b26fe7.bindPopup(popup_118a48da1344b36f4a90f1c632da8a51)
#         ;
#
#
#
#
#             var marker_117a13583f0011df0fc40793c3b934f4 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_e3029d8061b25872a88aff819413b513);
#
#
#         var popup_b7cebdcf5acf35896c07e12aa72512b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acf70342ada66cfc5c89aa5fd261c17c = $(`&lt;div id=&quot;html_acf70342ada66cfc5c89aa5fd261c17c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_b7cebdcf5acf35896c07e12aa72512b7.setContent(html_acf70342ada66cfc5c89aa5fd261c17c);
#
#
#
#         marker_117a13583f0011df0fc40793c3b934f4.bindPopup(popup_b7cebdcf5acf35896c07e12aa72512b7)
#         ;
#
#
#
#
#             var marker_350a64df95ecc0dafe4bac926a123bb9 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_e3029d8061b25872a88aff819413b513);
#
#
#         var popup_ab2ad4610f119bbd1f12a2898ddda522 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9d468c5e05612b0a77fdaf0b34efa5e = $(`&lt;div id=&quot;html_e9d468c5e05612b0a77fdaf0b34efa5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_ab2ad4610f119bbd1f12a2898ddda522.setContent(html_e9d468c5e05612b0a77fdaf0b34efa5e);
#
#
#
#         marker_350a64df95ecc0dafe4bac926a123bb9.bindPopup(popup_ab2ad4610f119bbd1f12a2898ddda522)
#         ;
#
#
#
#
#             var marker_3619d7d0de84392ac275d0f94ae21aa2 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_e3029d8061b25872a88aff819413b513);
#
#
#         var popup_0b866882444c6780e0f798b1815dc0bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fcfa86ab2abfaeed89cdf537c05b6fb = $(`&lt;div id=&quot;html_5fcfa86ab2abfaeed89cdf537c05b6fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_0b866882444c6780e0f798b1815dc0bc.setContent(html_5fcfa86ab2abfaeed89cdf537c05b6fb);

# %%
import googlemaps

# %%
gmaps = googlemaps.Client(key = "AIzaSyAPYggkegajeOPIoeDgfJ6J23jZ2JYTH9o")

# %%
gmaps.geocode('춘천시',language='ko')
# Out:
# [{'address_components': [{'long_name': '춘천시',
#     'short_name': '춘천시',
#     'types': ['locality', 'political']},
#    {'long_name': '강원도',
#     'short_name': '강원도',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 강원도 춘천시',
#   'geometry': {'bounds': {'northeast': {'lat': 38.0850242, 'lng': 128.0296082},
#     'southwest': {'lat': 37.6756679, 'lng': 127.5061481}},
#    'location': {'lat': 37.8897796, 'lng': 127.7398952},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.0850242, 'lng': 128.0296082},
#     'southwest': {'lat': 37.6756679, 'lng': 127.5061481}}},
#   'place_id': 'ChIJq_vvHybkYjURBDWI49gjy3U',
#   'types': ['locality', 'political']}]

# %%
university_name=['경남대학교', '경상대학교', '창원대학교']

university_address = [] 
university_lat = [] 
university_lng = []

for name in university_name:
    tmp = gmaps.geocode(name, language='ko') 
    university_address.append(tmp[0].get('formatted_address'))
    tmp_loc = tmp[0].get('geometry') 
    university_lat.append(tmp_loc['location']['lat']) 
    university_lng.append(tmp_loc['location']['lng'])
    
for address, lat, lng, name in zip(university_address, university_lat, university_lng, university_name): 
    print('학교명:', name)
    print('주소: ', address)
    print('위도: ', str(lat), ' 경도:', str(lng))
    print('-' *70)
# Out:
# 학교명: 경남대학교
# 주소:  대한민국 창원시
# 위도:  35.18035  경도: 128.553385
# ----------------------------------------------------------------------
# 학교명: 경상대학교
# 주소:  대한민국 경상남도 진주시 진주대로 501
# 위도:  35.1530444  경도: 128.1010899
# ----------------------------------------------------------------------
# 학교명: 창원대학교
# 주소:  대한민국 경상남도 창원시 의창구 창원대학로 20
# 위도:  35.245595  경도: 128.691953
# ----------------------------------------------------------------------

# %%
lat,lng
# Out:
# (35.245595, 128.691953)

# %%
df = pd.read_excel('data/서울지역 대학교 위치.xlsx') 
df.set_index('학교명', inplace=True)

# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98],
tiles='Stamen Terrain', zoom_start=12)

# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)
    
# 지도보기 
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d1721b185adeb07f36f74a888aefbfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d1721b185adeb07f36f74a888aefbfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d1721b185adeb07f36f74a888aefbfd = L.map(
#                 &quot;map_5d1721b185adeb07f36f74a888aefbfd&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e29bcc204d3a934b554adb64c7d31eb = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5d1721b185adeb07f36f74a888aefbfd);
#
#
#             var marker_49b13a6a03a136a6779921d5b2638261 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_5d1721b185adeb07f36f74a888aefbfd);
#
#
#         var popup_b09a8901364f217368ade860d0b1a13a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fcbe0ecffbcd663b86952770542205d = $(`&lt;div id=&quot;html_6fcbe0ecffbcd663b86952770542205d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_b09a8901364f217368ade860d0b1a13a.setContent(html_6fcbe0ecffbcd663b86952770542205d);
#
#
#
#         marker_49b13a6a03a136a6779921d5b2638261.bindPopup(popup_b09a8901364f217368ade860d0b1a13a)
#         ;
#
#
#
#
#             var marker_b1411779de1a08e98e595fdfc7fea3ef = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_5d1721b185adeb07f36f74a888aefbfd);
#
#
#         var popup_409069bf290ccd16ae6618645a918de8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51a48b8e59630b61d4d5614ac90b0a8f = $(`&lt;div id=&quot;html_51a48b8e59630b61d4d5614ac90b0a8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_409069bf290ccd16ae6618645a918de8.setContent(html_51a48b8e59630b61d4d5614ac90b0a8f);
#
#
#
#         marker_b1411779de1a08e98e595fdfc7fea3ef.bindPopup(popup_409069bf290ccd16ae6618645a918de8)
#         ;
#
#
#
#
#             var marker_3c1eb137bd7abcb01398e5a995169f7c = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_5d1721b185adeb07f36f74a888aefbfd);
#
#
#         var popup_26e0e471fa52fb692b9336914e52ace8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0e6560ad6659fa371f31cda3d699435 = $(`&lt;div id=&quot;html_c0e6560ad6659fa371f31cda3d699435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_26e0e471fa52fb692b9336914e52ace8.setContent(html_c0e6560ad6659fa371f31cda3d699435);
#
#
#
#         marker_3c1eb137bd7abcb01398e5a995169f7c.bindPopup(popup_26e0e471fa52fb692b9336914e52ace8)
#         ;
#
#
#
#
#             var marker_ec86f1cf60c603fbb014f8abc6c8e248 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_5d1721b185adeb07f36f74a888aefbfd);
#
#
#         var popup_4d4c1d5d5e6e5955e37fbaa4c65d04e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5323a6dac457ef7dcab5f496fa600d11 = $(`&lt;div id=&quot;html_5323a6dac457ef7dcab5f496fa600d11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_4d4c1d5d5e6e5955e37fbaa4c65d04e6.setContent(html_5323a6dac457ef7dcab5f496fa600d11);
#
#
#
#         marker_ec86f1cf60c603fbb014f8abc6c8e248.bindPopup(popup_4d4c1d5d5e6e5955e37fbaa4c65d04e6)
#         ;
#
#
#
#
#             var marker_735b6e5767a6e978e5d93280c762e1cb = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_5d1721b185adeb07f36f74a888aefbfd);
#
#
#         var popup_ecb209d7effe65c913f1aef47bcf3228 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ddd81f115ad44e54ea1a7d9f307aac3a = $(`&lt;div id=&quot;html_ddd81f115ad44e54ea1a7d9f307aac3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_ecb209d7effe65c913f1aef47bcf3228.setContent(html_ddd81f115ad44e54ea1a7d9f307aac3a);

# %%
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98],
tiles='Stamen Terrain', zoom_start=12)

# %%
# 대학교 위치정보를 CircleMarker로 표시
for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.CircleMarker([lat, lng],radius=10, # 원의 반지름
color='brown', # 원의 둘레 색상 fill=True,
fill_color='coral', # 원을 채우는 색 fill_opacity=0.7, # 투명도 popup=name
                        ).add_to(seoul_map)
# 지도보기 
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c7fd759c5b14578f30bb765f4912de9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c7fd759c5b14578f30bb765f4912de9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c7fd759c5b14578f30bb765f4912de9 = L.map(
#                 &quot;map_7c7fd759c5b14578f30bb765f4912de9&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ae5b3ea9d8ceea9169f978c60074197 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c7fd759c5b14578f30bb765f4912de9);
#
#
#             var circle_marker_00fb2499b6f49e61120cca4242aef475 = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c7fd759c5b14578f30bb765f4912de9);
#
#
#             var circle_marker_c72088130be87466b44aafdfcee78bbb = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c7fd759c5b14578f30bb765f4912de9);
#
#
#             var circle_marker_741f365fba42eab4fbdfd2e2c1f234df = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c7fd759c5b14578f30bb765f4912de9);
#
#
#             var circle_marker_09006b13843309ae3044f4d3f1571a0f = L.circleMarker(
#                 [37.4996227, 127.0060653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c7fd759c5b14578f30bb765f4912de9);
#
#
#             var circle_marker_1db09e8fb1ca5bc2f75a583a6803c837 = L.circleMarker(
#                 [37.5676455, 126.96161],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c7fd759c5b14578f30bb765f4912de9);
#
#
#             var circle_marker_3a8349db4ca0c16d0847c757219b1a4e = L.circleMarker(
#                 [37.5407625, 127.0793428],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin
